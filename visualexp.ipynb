# %%
import pandas as pd
import matplotlib.pyplot as plt
from math import *

# %% [markdown]
# Define the functions to calculate the thepretical value

# %%
def f(x,c):
	return exp(-1*(c*(1-x))**2)  #c**2

def gamma(c):
  maxt = 100
  z=0
  for i in range(1,maxt):
    z=f(z,c)
  return(z, 1-f(z,c)-(c**2)*z*((1-z)**2), 1- ((c**2)/3.0)*(1-(1-z)**3))#(\gamma,lowerbound,upperbound)

def expedge(n,c):
	return(0.5*c*(sqrt(n))*(n-1))

# %% [markdown]
# c=1.7, t= \infty

# %%
# Read data from CSV file
df = pd.read_csv('edgecol_output_data_c=1.7.csv') #change file name according to need

table =  df.iloc[:, 1].apply(lambda x: [int(i) for i in x.strip('[]').split(', ')])

n_vertex =  [lst[2] for lst in table]
m_final =  [lst[-6] for lst in table]
m_initial =  [lst[3] for lst in table]

thval= gamma(1.7)
ub = thval[2]
lb = thval[1]

c=1.7 # change accordingly
m_ub = [ub*expedge(n,c) for n in n_vertex]
m_lb = [lb*expedge(n,c) for n in n_vertex]

k = 16

# Plotting the data
plt.figure(figsize=(8, 6))  # Adjust the figure size as needed
plt.scatter(n_vertex, m_final, s=5, label = 'Number of edges in the core')
plt.scatter(n_vertex, m_initial, s=5, label = 'Initial number of edges')
plt.plot(n_vertex, m_ub, label = 'Theoretical upper bound on the \n number of edges in the core')
plt.plot(n_vertex, m_lb, label = 'Theoretical lower bound on the \n number of edges in the core')
plt.title('Size of the core with c=1.7', fontsize= k)
plt.xlabel('Number of vertices', fontsize= k)
plt.ylabel('Number of edges', fontsize= k)
plt.legend(fontsize= k)
plt.xticks(fontsize=k)
plt.yticks(fontsize=k)
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [markdown]
# c=1.7, t=8

# %%
# Read data from CSV file
df = pd.read_csv('edgecol_output_data_c=1.7.csv') #change file name according to need

table =  df.iloc[:, 1].apply(lambda x: [int(i) for i in x.strip('[]').split(', ')])

t=8 #number of iterations

n_vertex =  [lst[2] for lst in table]
m_final =  [lst[8*t+3] for lst in table]
m_initial =  [lst[3] for lst in table]

#modify the theoretical bound accordingly 

def f(x,c):
	return exp(-1*(c*(1-x))**2)  #c**2

def gammat(c):
  maxt = t
  z=0
  for i in range(0,maxt+1):
    #print(i, z, 1-f(z,c)-(c**2)*z*((1-z)**2), 1- ((c**2)/3.0)*(1-(1-z)**3))
    z=f(z,c)
  return(z, 1-f(z,c)-(c**2)*z*((1-z)**2), 1- ((c**2)/3.0)*(1-(1-z)**3))#(\gamma,lowerbound,upperbound)

def expedge(n,c):
	return(0.5*c*(sqrt(n))*(n-1))

thval= gammat(1.7)
ub = thval[2]
lb = thval[1]

c=1.7 # change accordingly
m_ub = [ub*expedge(n,c) for n in n_vertex]
m_lb = [lb*expedge(n,c) for n in n_vertex]

k=16

# Plotting the data
plt.figure(figsize=(8, 6))  # Adjust the figure size as needed
plt.scatter(n_vertex, m_final, s=5, label = 'Number of edges in the 8-core ')
plt.scatter(n_vertex, m_initial, s=5, label = 'Initial number of edges')
plt.plot(n_vertex, m_ub, label = 'Theoretical upper bound on the \n number of edges in the 8-core')
plt.plot(n_vertex, m_lb, label = 'Theoretical lower bound on the \n number of edges in the 8-core')
plt.title('Size of the 8-core with c=1.7', fontsize= k)
plt.xlabel('Number of vertices', fontsize= k)
plt.ylabel('Number of edges', fontsize= k)
plt.legend(fontsize= k)
plt.xticks(fontsize=k)
plt.yticks(fontsize=k)
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [markdown]
# c=2.0, t=5

# %%
# Read data from CSV file
df = pd.read_csv('edgecol_output_data_c=2.0.csv') #change file name according to need

table =  df.iloc[:, 1].apply(lambda x: [int(i) for i in x.strip('[]').split(', ')])

t=5 #number of iterations

n_vertex =  [lst[2] for lst in table]
m_final =  [lst[8*(min(t,lst[0]))+3] for lst in table]
m_initial =  [lst[3] for lst in table]

#modify the theoretical bound accordingly 

def f(x,c):
	return exp(-1*(c*(1-x))**2)  #c**2

def gammat(c):
  maxt = t
  z=0
  for i in range(0,maxt+1):
    #print(i, z, 1-f(z,c)-(c**2)*z*((1-z)**2), 1- ((c**2)/3.0)*(1-(1-z)**3))
    z=f(z,c)
  return(z, 1-f(z,c)-(c**2)*z*((1-z)**2), 1- ((c**2)/3.0)*(1-(1-z)**3))#(\gamma,lowerbound,upperbound)

def expedge(n,c):
	return(0.5*c*(sqrt(n))*(n-1))

thval= gammat(2.0)
ub = thval[2]
lb = thval[1]

c=2.0 # change accordingly
m_ub = [ub*expedge(n,c) for n in n_vertex]
m_lb = [lb*expedge(n,c) for n in n_vertex]

k = 16

# Plotting the data
plt.figure(figsize=(8, 6))  # Adjust the figure size as needed
plt.scatter(n_vertex, m_final, s=5, label = 'Number of edges in the 5-core')
plt.scatter(n_vertex, m_initial, s=5, label = 'Initial number of edges')
plt.plot(n_vertex, m_ub, label = 'Theoretical upper bound on the \n number of edges in the 5-core')
plt.plot(n_vertex, m_lb, label = 'Theoretical lower bound on the \n number of edges in the 5-core')
plt.title('Size of the 5-core with c=2.0', fontsize= k)
plt.xlabel('Number of vertices', fontsize= k)
plt.ylabel('Number of edges', fontsize= k)
plt.legend(fontsize= k)
plt.xticks(fontsize=k)
plt.yticks(fontsize=k)
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [markdown]
# Plotting another file (c=2.0, t= \infty)

# %%
# Read data from CSV file
df = pd.read_csv('edgecol_output_data_c=2.0.csv') #change file name according to need

table =  df.iloc[:, 1].apply(lambda x: [int(i) for i in x.strip('[]').split(', ')])

n_vertex =  [lst[2] for lst in table]
m_final =  [lst[-6] for lst in table]
m_initial =  [lst[3] for lst in table]

thval= gamma(2.0)
ub = thval[2]
lb = thval[1]

c=2.0 # change accordingly
m_ub = [ub*expedge(n,c) for n in n_vertex]
m_lb = [lb*expedge(n,c) for n in n_vertex]

k=16

# Plotting the data
plt.figure(figsize=(8, 6))  # Adjust the figure size as needed
plt.scatter(n_vertex, m_final, s=5, label = 'Number of edges in the core')
plt.scatter(n_vertex, m_initial, s=5, label = 'Initial number of edges')
plt.plot(n_vertex, m_ub, label = 'Theoretical upper bound on the \n number of edges in the core')
plt.plot(n_vertex, m_lb, label = 'Theoretical lower bound on the \n number of edges in the core')
plt.title('Size of the core with c=2.0', fontsize=k)
plt.xlabel('Number of vertices', fontsize=k)
plt.ylabel('Number of edges', fontsize=k)
plt.legend(fontsize= k)
plt.xticks(fontsize=k)
plt.yticks(fontsize=k)
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [markdown]
# n=1500

# %%
# Read data from CSV file
df = pd.read_csv('edgecol_output_data_n=1500.csv') #change file name according to need

table =  df.iloc[:, 1].apply(lambda x: [int(i) for i in x.strip('[]').split(', ')])

n_vertex =  [lst[2] for lst in table]
m_final =  [lst[-6] for lst in table]
m_initial =  [lst[3] for lst in table]
itr =  [lst[0]*100 for lst in table]

cval = df.iloc[:, 0]
cval = cval.tolist()

n=1500 # change accordingly

m_ub = [gamma(c)[2]*expedge(n,c) for c in cval]
m_lb = [gamma(c)[1]*expedge(n,c) for c in cval]

# Plotting the data
plt.figure(figsize=(8, 6))  # Adjust the figure size as needed
plt.scatter(cval, m_final, s=5, label = 'Number of edges in the core') 
plt.scatter(cval, m_initial, s=5, label = 'Initial number of edges') 
plt.plot(cval, m_ub, label = 'Theoretical upper bound number of edges in the core') 
plt.plot(cval, m_lb, label = 'Theoretical lower bound number of edges in the core') 
plt.plot(cval, itr, label = 'Number of iterations*100 to reach the core the core') 
plt.title('Size of the core with n=1500')
plt.xlabel('c')
plt.ylabel('Number of edges')
plt.legend(fontsize='large')
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [markdown]
# n=1500, t=\infty

# %%
# Read data from CSV file
df = pd.read_csv('edgecol_output_data_n=1500.csv') #change file name according to need

table =  df.iloc[:, 1].apply(lambda x: [int(i) for i in x.strip('[]').split(', ')])

n_vertex =  [lst[2] for lst in table]
m_final =  [lst[-6] for lst in table]
m_initial =  [lst[3] for lst in table]


cval = df.iloc[:, 0]
cval = cval.tolist()

st = 62
fin = 150

cval=cval[st:fin]
n_vertex =  n_vertex[st:fin]
m_final =  m_final[st:fin]
m_initial =  m_initial[st:fin]




n=1500 # change accordingly

m_ub = [gamma(c)[2]*expedge(n,c) for c in cval]
m_lb = [gamma(c)[1]*expedge(n,c) for c in cval]

k=16

# Plotting the data
plt.figure(figsize=(8, 6))  # Adjust the figure size as needed
plt.scatter(cval, m_final, s=5, label = 'Number of edges in the core') 
plt.scatter(cval, m_initial, s=5, label = 'Initial number of edges') 
plt.plot(cval, m_ub, label = 'Theoretical upper bound on the \n number of edges in the core') 
plt.plot(cval, m_lb, label = 'Theoretical lower bound on the \n number of edges in the core')  
plt.title('Size of the core with n=1500', fontsize=k)
plt.xlabel('c', fontsize=k)
plt.ylabel('Number of edges', fontsize=k)
plt.legend(fontsize= k)
plt.xticks(fontsize=k)
plt.yticks(fontsize=k)
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()
